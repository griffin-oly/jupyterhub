# %% [markdown]
# <img src="attachment:Rebecca_eyes6.png" width="400" align="left">

# %% [markdown]
# # <center>Admin Tasks and Notes </center>
# ## Current users status
# Current users and notes related to the Jupyter Space

# %%
import pandas as pd
# excel file in current directory as notebook
excel_file = 'JupyterUsers.xlsx'  # new format xlsx
users = pd.read_excel(excel_file) # Read into variable users
users.head()
# Out:
#          Full Name         Username         Home Directory Admin Configured
# 0  Goodman Griffin  griffin.goodman  /home/griffin.goodman     Y          Y
# 1    Chris Vallier    chris.vallier    /home/chris.vallier     Y          Y
# 2       John Smith       john.smith       /home/john.smith     N          N
# 3         Joe Test              NaN                    NaN   NaN        NaN
# 4      Sally Jones              NaN                    NaN   NaN        NaN

# %% [markdown]
# ## Modules Installed currently
# Python 3 and Python 2 kernels installed and working
# Python modules:
# - [x] matplotlib - data visualization
# - [x] NumPy - numerical data functionality
# - [x] Pandas
# - [x] Cython
# - [x] Plotnine
# - [x] Seaborn
# - [x] statsmodels
# - [x] Missingno
# - [x] Pyjanitor
# - [x] Plotly
# - [x] Cufflinks
# - [x] scikit-learn
# - [x] mlxtend
# - [x] dask
# - [x] dask-ml
# - [ ] pandas-montecarlo - I was unable to find this one.

# %% [markdown]
# ## Current librarys in the base enviroment.

# %%
# !conda list
# Out:
# # packages in environment at /usr/local/anaconda:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# _r-mutex                  1.0.0               anacondar_1    r
# alabaster                 0.7.12                   py37_0
# alembic                   0.9.9                      py_0    conda-forge
# anaconda                  custom                   py37_0
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.2                    py37_0
# anaconda-project          0.8.2                    py37_0
# appdirs                   1.4.3            py37h28b3542_0
# asn1crypto                0.24.0                   py37_0
# astroid                   2.1.0                    py37_0
# astropy                   3.1              py37h7b6447c_0
# async_generator           1.10                       py_0    conda-forge
# atomicwrites              1.2.1                    py37_0
# ...

# %% [markdown]
# ## Current enviroments configured:

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local/anaconda
# py27                     /usr/local/anaconda/envs/py27
# tensorflow               /usr/local/anaconda/envs/tensorflow

# %% [markdown]
# ## Create secret key
# - From terminal window
# > - ssh-keygen
# > - hit enter 3 times to accept defaults
# >> - copy public key from .ssh up to github account.

# %% [markdown]
# ## Github location for admin notes
# ***
# * Admin notes git location:
#
# [Github repo link](https://github.com/griffin-oly/jupyterhub)
# * From terminal to push changes:
# > - git status
# > - git commit -am "Change discription"
# > - git push
